# %%
import sys
import os

# Add the project root (parent of "scripts") to sys.path
sys.path.append(os.path.abspath(".."))
from scripts.eoapi_preprocessor import EOAPIPreprocessor

# File paths
eoapi_file = "../data/satellite_results/1_Sentinel1_from_openEO.tif"       # EO API original
eoapi_db_file = "../data/satellite_results/2_Sentinel1_converted_dB.tif"  # output

# Initialize preprocessor
preprocessor = EOAPIPreprocessor(eoapi_file, eoapi_db_file)

# Convert EO API image to dB
preprocessor.convert_to_db()

# Visualize before and after
preprocessor.visualize_conversion()
# Out:
# ✅ EO API image converted to dB and saved as ../data/satellite_results/2_Sentinel1_converted_dB.tif
